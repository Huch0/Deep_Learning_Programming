# %% [markdown]
# # LAB 2: YOLO detection model

# %% [markdown]
# <h4><div style="text-align: right"> Due date: 15:00 Oct 28, 2024.  </div> <br>
# <div style="text-align: right"> Please upload your file and final-report at PLATO before the class in the form of [ID_Name_Lab1.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - You must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# <h2><span style="color:blue">[202055623] [허치영]</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2024-10-30 15:08:04.574757

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" # Arrange GPU devices starting from 0 
os.environ["CUDA_VISIBLE_DEVICES"]= "3" # Set the GPU 3 to use

# %%
# Set the random seed for reproducibility
seed = 0
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print("Random seed set to:", seed)
# Out:
# Random seed set to: 0

# %%
import sys
import platform
import torch

print("Python version")
print(sys.version_info)

print("\nOS information")
print(platform.platform())

print("\nIs GPU available?")
print(torch.cuda.is_available())

# print("\nCPU information")
# !cat /proc/cpuinfo

# print("\nMemory information")
# !cat /proc/meminfo

if torch.cuda.is_available():
    print("\nGPU information")
    # !nvidia-smi
    device = torch.device('cuda')
elif torch.mps.device_count() > 0:
    device = 'mps'
else:
    device = torch.device('cpu')

print(f"\ndevice={device}")
os.chdir('/home/dlpro24/24-2DLProgramming/huch0')
print(os.getcwd())
# Out:
# Python version
# sys.version_info(major=3, minor=8, micro=19, releaselevel='final', serial=0)
#
# OS information
# Linux-5.4.0-193-generic-x86_64-with-glibc2.17
#
# Is GPU available?
# True
#
# GPU information
# Wed Oct 30 15:08:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX A5000               On  | 00000000:01:00.0 Off |                  Off |
# | 30%   32C    P8              16W / 230W |  24066MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000               On  | 00000000:23:00.0 Off |                  Off |
# | 30%   32C    P8              18W / 230W |  12640MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000               On  | 00000000:41:00.0 Off |                  Off |
# | 30%   41C    P2              58W / 230W |  19217MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000               On  | 00000000:61:00.0 Off |                  Off |
# | 30%   36C    P8              19W / 230W |  10890MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000               On  | 00000000:81:00.0 Off |                  Off |
# | 30%   34C    P8              21W / 230W |   5386MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000               On  | 00000000:A1:00.0 Off |                  Off |
# | 30%   41C    P2              61W / 230W |  19065MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000               On  | 00000000:C1:00.0 Off |                  Off |
# | 30%   32C    P8              18W / 230W |  20548MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000               On  | 00000000:E1:00.0 Off |                  Off |
# | 30%   33C    P8              18W / 230W |  12078MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   1453843      C   /usr/bin/python3                          11916MiB |
# |    0   N/A  N/A   1506439      C   /usr/bin/python3                          12140MiB |
# |    1   N/A  N/A   1820307      C   /home/team102/miniconda3/bin/python        5776MiB |
# |    1   N/A  N/A   2905578      C   /usr/bin/python3                           6854MiB |
# |    2   N/A  N/A   2727850      C   /usr/bin/python3                           4218MiB |
# |    2   N/A  N/A   2730335      C   /usr/bin/python3                           6854MiB |
# |    3   N/A  N/A   2609017      C   /usr/bin/python3                          10880MiB |
# |    4   N/A  N/A   2751739      C   python                                     5374MiB |
# |    5   N/A  N/A   2766926      C   /usr/bin/python3                           6342MiB |
# |    5   N/A  N/A   2799456      C   /usr/bin/python3                           3292MiB |
# |    6   N/A  N/A   2462305      C   ...miniconda3/envs/sukamura/bin/python    15198MiB |
# |    6   N/A  N/A   2600448      C   /home/team107/miniconda3/bin/python        5340MiB |
# |    7   N/A  N/A   2378207      C   /home/team108/miniconda3/bin/python       12068MiB |
# +---------------------------------------------------------------------------------------+
#
# device=cuda
# /home/dlpro24/24-2DLProgramming/huch0

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.1 slope for negative part (default=0.01))
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.1   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model (0.685 mAP) since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.7 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"


class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        # root: Root directory of the dataset
        # list_file: File containing the list of image filenames and their corresponding bounding boxes and classes
        # train: True if the dataset is the training dataset, False otherwise
        # transform: Optional transform to be applied to the images.

        self.image_size = 448 # Image size (448x448)
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = [] # List of image filenames
        self.boxes = [] # List of bounding boxes for each image
        self.labels = [] # List of classes for each image

        # Transformations for data augmentation and resizing
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
                                     transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])

        with open(list_file) as f:
            lines = f.readlines()

        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)

    def img_pre_process(self, img, boxes, labels):

        # Flip the image horizontally
        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:, 0] = x_min
            boxes[:, 2] = x_max
            img = im_lr

        # Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)

        # Image translation
        if random.random() < 0.5:
            center = (boxes[:, 2:] + boxes[:, :2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)

            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))

            if w_range < 0 and h_range < 0:
                shifted_img[:height+h_range, :width+w_range, :] = img[-h_range:, -w_range:, :]

            elif w_range < 0 and h_range >= 0:
                shifted_img[h_range:, :width+w_range, :] = img[:height-h_range, -w_range:, :]

            elif w_range >= 0 and h_range >= 0:
                shifted_img[h_range:, w_range:, :] = img[:height-h_range, :width-w_range, :]

            elif w_range >= 0 and h_range < 0:
                shifted_img[:height+h_range, w_range:, :] = img[-h_range:, :width-w_range, :]

            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range

            mask1 = (center[:, 0] > 0) & (center[:, 0] < width)
            mask2 = (center[:, 1] > 0) & (center[:, 1] < height)
            mask = (mask1 & mask2).view(-1, 1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1, 4)

            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift

                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in

        # Image cropping
        if random.random() < 0.5:
            center = (boxes[:, 2:] + boxes[:, :2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height, height))
            w = int(random.uniform(0.6*width, width))
            x = int(random.uniform(0, width-w))
            y = int(random.uniform(0, height-h))

            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:, 0] > 0) & (center[:, 0] < w)
            mask2 = (center[:, 1] > 0) & (center[:, 1] < h)
            mask = (mask1 & mask2).view(-1, 1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1, 4)

            if (len(boxes_in) != 0):
                box_shift = torch.FloatTensor([x, y, x, y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:, 0] = boxes_in[:, 0].clamp_(min=0, max=w)
                boxes_in[:, 2] = boxes_in[:, 2].clamp_(min=0, max=w)
                boxes_in[:, 1] = boxes_in[:, 1].clamp_(min=0, max=h)
                boxes_in[:, 3] = boxes_in[:, 3].clamp_(min=0, max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped

        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7  # 7x7 grid
        h, w, _ = img.shape
        boxes /= torch.Tensor([w, h, w, h]).expand_as(boxes)  # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30))  # 7x7x30
        cell_size = 1./grid_size  # 1/7

        wh = boxes[:, 2:] - boxes[:, :2] # width, height
        cxcy = (boxes[:, 2:] + boxes[:, :2]) / 2 # center

        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i]  # center pixel
            ij = (cxcy_sample/cell_size).ceil()-1 # Index of the cell containing the center
            target[int(ij[1]), int(ij[0]), 4] = 1 # Confidence score
            target[int(ij[1]), int(ij[0]), 9] = 1 # Confidence score
            target[int(ij[1]), int(ij[0]), int(labels[i])+9] = 1 # Class label

            xy = ij*cell_size
            delta_xy = (cxcy_sample - xy)/cell_size  # Converting delta_xy to the size
            # relative to the bounds of the grid cell
            target[int(ij[1]), int(ij[0]), 2:4] = wh[i]
            target[int(ij[1]), int(ij[0]), :2] = delta_xy
            target[int(ij[1]), int(ij[0]), 7:9] = wh[i]
            target[int(ij[1]), int(ij[0]), 5:7] = delta_xy

        return target

    def RandomBrightness(self, bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr, cv2.COLOR_BGR2HSV)
            h, s, v = cv2.split(hsv)
            adjust = random.choice([0.5, 1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h, s, v))
            bgr = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
        return bgr

    def RandomSaturation(self, bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr, cv2.COLOR_BGR2HSV)
            h, s, v = cv2.split(hsv)
            adjust = random.choice([0.5, 1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h, s, v))
            bgr = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
        return bgr

    def RandomHue(self, bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr, cv2.COLOR_BGR2HSV)
            h, s, v = cv2.split(hsv)
            adjust = random.choice([0.5, 1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h, s, v))
            bgr = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self, bgr):
        if random.random() < 0.5:
            bgr = cv2.blur(bgr, (5, 5))
        return bgr

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)

        target = self.generate_target(img, boxes, labels)  # 7x7x30

        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1

        return img, target

    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()

        self.pre_train_net = nn.Sequential(
            ################
            ### Fill out ###
            ################

            # Conv1
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=7, stride=2, padding=3),
            nn.LeakyReLU(negative_slope=0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Conv2
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Conv3
            nn.Conv2d(in_channels=192, out_channels=128, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv4
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv5
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv6
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Conv7
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv8
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv9
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv10
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv11
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv12
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv13
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv14
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv15
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv16
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Conv17
            nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv18
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1)
        )

        self.post_net = nn.Sequential(
            ################
            ### Fill out ###
            ################

            # Conv19
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv20
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv21
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1),
            # Conv22
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.1)
        )

        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )

        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )

        # self.pre_train_net.to(device)
        # self.post_net.to(device)
        # self.FC1.to(device)
        # self.FC2.to(device)
        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()

        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)

        output = self.post_net(output)
        if torch.isnan(output).any():
            # print(output)
            raise ValueError("post_net")

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj

    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        ################
        ### Fill out ###
        ################
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        contain_target = target[contain].contiguous().view(-1,30)

        pred_class_probs = contain_pred[:,10:] # [Batch_size*7*7, 20]
        target_class_probs = contain_target[:,10:] # [Batch_size*7*7, 20]

        # Compute the classification error only for the cells that contain an object
        prob_loss = F.mse_loss(pred_class_probs, target_class_probs, size_average = False)

        return prob_loss

    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:,:,:,4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        ################
        ### Fill out ###
        ################

        not_contain_pred = pred[not_contain].contiguous().view(-1,30) # Only cell which does not contain the object are remained
        not_contain_target = target[not_contain].contiguous().view(-1,30)
        
        noobj_bbox1 = F.mse_loss(not_contain_pred[:,4], not_contain_target[:,4], size_average = False)
        noobj_bbox2 = F.mse_loss(not_contain_pred[:,9], not_contain_target[:,9], size_average = False)

        noobj_loss1 = noobj_bbox1 + noobj_bbox2
        
        return noobj_loss1


    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        contain_pred = pred[contain].contiguous().view(-1 ,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping [Batch_size*7*7*2, 5]

        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5) # Reshaping [Batch_size*7*7*2, 5]

        # Note that, We assign one predictor to be "responsible" for predicting
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables

        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_() # Create the mask
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_()
        # contain_obj_mask = torch.ByteTensor(box_target.size()).zero_().to(device)
        # contain_noobj_mask = torch.ByteTensor(box_target.size()).zero_().to(device)

        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence
                                                                   # of the cell which contains object
        # target_iou_gt = torch.zeros(box_target[:,0].size()).to(device)

        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            
            box_p_coord[:, :2] = box_p[:, :2]/7. - 0.5 * box_p[:, 2:4]
            box_p_coord[:, 2:4] = box_p[:, :2]/7. + 0.5 * box_p[:, 2:4]

            box_t = box_target[i].contiguous().view(-1,5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            
            box_t_coord[:, :2] = box_t[:, :2]/7. - 0.5 * box_t[:, 2:4]
            box_t_coord[:, 2:4] = box_t[:, :2]/7. + 0.5 * box_t[:, 2:4]

            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes,

            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1

            target_iou_gt[i+max_idx] = gt_iou.data.cuda()
            # target_iou_gt[i+max_idx] = gt_iou.data.to(device)

        # target_iou_gt = target_iou_gt.to(device)

        ## For the cell which contains object
        contain_box_pred = box_pred[contain_obj_mask].view(-1,5)

        ## For the cell which does not contain object
        not_contain_box_pred = box_pred[contain_noobj_mask].view(-1,5)

        ## For target domain
        contain_box_target = box_target[contain_obj_mask].view(-1,5)
        not_contain_box_target = box_target[contain_noobj_mask].view(-1,5)
        not_contain_box_target[:,4] = 0

        ## For the GT IoU
        contain_iou_target = target_iou_gt[contain_obj_mask[:, 0]]

        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)

        return obj_loss, xy_loss, wh_loss, noobj_loss2

    def compute_iou(self, box_p, box_t):
        # [x_min, y_min, x_max, y_max]
        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]

        box_p = box_p.unsqueeze(1).expand(2,1,4) # [2, 4] -> [2, 1, 4]
        box_t = box_t.unsqueeze(0).expand(2,1,4) # [1, 4] -> [2, 1, 4]
        
        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]

        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]

        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0

        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)

        iou = inter_area / (pred_area + target_area - inter_area)

        return iou



    def forward(self,pred,target):

        batch_size = pred.size()[0]

        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)

        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)
            
        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
file_root = './lab2/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='./lab2/utils/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)
# train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=0)

model = YOLO()
state_dict = torch.load('./lab2/pre_train.pt', weights_only=True)
# state_dict = torch.load('./lab2/pre_train.pt', map_location=device, weights_only=True)
model.load_state_dict(state_dict['state_dict'])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

print('pre_train_complete')
criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)

        pred = model(images)
        loss = criterion(pred, target)

        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:324.9547, average_loss: 386.9176
# Epoch [1/15], Iter [20,430] Loss:114.9765, average_loss: 276.2181
# Epoch [1/15], Iter [30,430] Loss:39.3157, average_loss: 201.9094
# Epoch [1/15], Iter [40,430] Loss:20.6769, average_loss: 157.5795
# Epoch [1/15], Iter [50,430] Loss:10.4195, average_loss: 128.1936
# Epoch [1/15], Iter [60,430] Loss:5.1906, average_loss: 108.1884
# Epoch [1/15], Iter [70,430] Loss:4.5134, average_loss: 93.3929
# Epoch [1/15], Iter [80,430] Loss:3.1873, average_loss: 82.3151
# Epoch [1/15], Iter [90,430] Loss:3.8707, average_loss: 73.6338
# Epoch [1/15], Iter [100,430] Loss:3.7450, average_loss: 66.5994
# Epoch [1/15], Iter [110,430] Loss:3.1058, average_loss: 60.8121
# Epoch [1/15], Iter [120,430] Loss:2.6455, average_loss: 56.0101
# Epoch [1/15], Iter [130,430] Loss:2.2646, average_loss: 51.9191
# Epoch [1/15], Iter [140,430] Loss:2.5919, average_loss: 48.4181
# Epoch [1/15], Iter [150,430] Loss:1.6456, average_loss: 45.3526
# Epoch [1/15], Iter [160,430] Loss:2.7442, average_loss: 42.6765
# Epoch [1/15], Iter [170,430] Loss:2.4171, average_loss: 40.3100
# Epoch [1/15], Iter [180,430] Loss:1.8746, average_loss: 38.2236
# Epoch [1/15], Iter [190,430] Loss:3.2021, average_loss: 36.3522
# Epoch [1/15], Iter [200,430] Loss:2.5270, average_loss: 34.6517
# Epoch [1/15], Iter [210,430] Loss:1.6293, average_loss: 33.1114
# Epoch [1/15], Iter [220,430] Loss:2.3913, average_loss: 31.7107
# Epoch [1/15], Iter [230,430] Loss:2.4193, average_loss: 30.4237
# Epoch [1/15], Iter [240,430] Loss:2.5124, average_loss: 29.2422
# Epoch [1/15], Iter [250,430] Loss:1.6974, average_loss: 28.1475
# Epoch [1/15], Iter [260,430] Loss:1.6004, average_loss: 27.1525
# Epoch [1/15], Iter [270,430] Loss:1.4617, average_loss: 26.2217
# Epoch [1/15], Iter [280,430] Loss:1.5848, average_loss: 25.3547
# Epoch [1/15], Iter [290,430] Loss:1.5290, average_loss: 24.5515
# Epoch [1/15], Iter [300,430] Loss:1.4533, average_loss: 23.7961
# Epoch [1/15], Iter [310,430] Loss:2.0142, average_loss: 23.0946
# Epoch [1/15], Iter [320,430] Loss:2.3941, average_loss: 22.4253
# Epoch [1/15], Iter [330,430] Loss:1.3839, average_loss: 21.7968
# Epoch [1/15], Iter [340,430] Loss:2.2632, average_loss: 21.2176
# Epoch [1/15], Iter [350,430] Loss:1.7745, average_loss: 20.6582
# Epoch [1/15], Iter [360,430] Loss:1.6327, average_loss: 20.1294
# Epoch [1/15], Iter [370,430] Loss:2.5218, average_loss: 19.6368
# Epoch [1/15], Iter [380,430] Loss:1.5681, average_loss: 19.1718
# Epoch [1/15], Iter [390,430] Loss:1.3849, average_loss: 18.7261
# Epoch [1/15], Iter [400,430] Loss:2.2307, average_loss: 18.3018
# Epoch [1/15], Iter [410,430] Loss:2.1782, average_loss: 17.8957
# Epoch [1/15], Iter [420,430] Loss:1.6762, average_loss: 17.5109
# Epoch [1/15], Iter [430,430] Loss:1.1485, average_loss: 17.1435
# Epoch [2/15], Iter [10,430] Loss:2.0956, average_loss: 1.5332
# Epoch [2/15], Iter [20,430] Loss:2.4038, average_loss: 1.6610
# Epoch [2/15], Iter [30,430] Loss:1.2188, average_loss: 1.6667
# Epoch [2/15], Iter [40,430] Loss:1.0900, average_loss: 1.6711
# Epoch [2/15], Iter [50,430] Loss:1.0831, average_loss: 1.6752
# Epoch [2/15], Iter [60,430] Loss:1.7517, average_loss: 1.6389
# Epoch [2/15], Iter [70,430] Loss:1.6645, average_loss: 1.6248
# Epoch [2/15], Iter [80,430] Loss:1.8188, average_loss: 1.6458
# Epoch [2/15], Iter [90,430] Loss:1.3165, average_loss: 1.6331
# Epoch [2/15], Iter [100,430] Loss:1.2976, average_loss: 1.6258
# Epoch [2/15], Iter [110,430] Loss:1.2582, average_loss: 1.6317
# Epoch [2/15], Iter [120,430] Loss:1.2853, average_loss: 1.6270
# Epoch [2/15], Iter [130,430] Loss:1.3163, average_loss: 1.6186
# Epoch [2/15], Iter [140,430] Loss:1.0716, average_loss: 1.6131
# Epoch [2/15], Iter [150,430] Loss:1.4658, average_loss: 1.6149
# Epoch [2/15], Iter [160,430] Loss:1.2302, average_loss: 1.6093
# Epoch [2/15], Iter [170,430] Loss:1.5984, average_loss: 1.6011
# Epoch [2/15], Iter [180,430] Loss:1.8306, average_loss: 1.5954
# Epoch [2/15], Iter [190,430] Loss:1.8123, average_loss: 1.5836
# Epoch [2/15], Iter [200,430] Loss:1.7066, average_loss: 1.5747
# Epoch [2/15], Iter [210,430] Loss:1.7853, average_loss: 1.5685
# Epoch [2/15], Iter [220,430] Loss:1.5705, average_loss: 1.5552
# Epoch [2/15], Iter [230,430] Loss:1.3856, average_loss: 1.5583
# Epoch [2/15], Iter [240,430] Loss:1.7805, average_loss: 1.5618
# Epoch [2/15], Iter [250,430] Loss:1.9042, average_loss: 1.5575
# Epoch [2/15], Iter [260,430] Loss:1.1780, average_loss: 1.5468
# Epoch [2/15], Iter [270,430] Loss:1.5478, average_loss: 1.5502
# Epoch [2/15], Iter [280,430] Loss:1.1941, average_loss: 1.5380
# Epoch [2/15], Iter [290,430] Loss:1.2120, average_loss: 1.5282
# Epoch [2/15], Iter [300,430] Loss:1.2766, average_loss: 1.5248
# Epoch [2/15], Iter [310,430] Loss:0.7261, average_loss: 1.5187
# Epoch [2/15], Iter [320,430] Loss:0.8454, average_loss: 1.5190
# Epoch [2/15], Iter [330,430] Loss:1.4636, average_loss: 1.5165
# Epoch [2/15], Iter [340,430] Loss:1.0806, average_loss: 1.5057
# Epoch [2/15], Iter [350,430] Loss:1.3019, average_loss: 1.5043
# Epoch [2/15], Iter [360,430] Loss:1.3003, average_loss: 1.4961
# Epoch [2/15], Iter [370,430] Loss:0.9649, average_loss: 1.4945
# Epoch [2/15], Iter [380,430] Loss:2.1800, average_loss: 1.4981
# Epoch [2/15], Iter [390,430] Loss:0.9877, average_loss: 1.4930
# Epoch [2/15], Iter [400,430] Loss:1.5945, average_loss: 1.4881
# Epoch [2/15], Iter [410,430] Loss:1.3939, average_loss: 1.4876
# Epoch [2/15], Iter [420,430] Loss:1.1163, average_loss: 1.4831
# Epoch [2/15], Iter [430,430] Loss:2.6435, average_loss: 1.4811
# Epoch [3/15], Iter [10,430] Loss:1.2103, average_loss: 1.2945
# Epoch [3/15], Iter [20,430] Loss:1.3910, average_loss: 1.2197
# Epoch [3/15], Iter [30,430] Loss:1.0404, average_loss: 1.2049
# Epoch [3/15], Iter [40,430] Loss:1.6410, average_loss: 1.2420
# Epoch [3/15], Iter [50,430] Loss:1.2681, average_loss: 1.2777
# Epoch [3/15], Iter [60,430] Loss:1.2137, average_loss: 1.2556
# Epoch [3/15], Iter [70,430] Loss:0.8889, average_loss: 1.3102
# Epoch [3/15], Iter [80,430] Loss:1.6509, average_loss: 1.2985
# Epoch [3/15], Iter [90,430] Loss:1.3800, average_loss: 1.3067
# Epoch [3/15], Iter [100,430] Loss:0.8794, average_loss: 1.2907
# Epoch [3/15], Iter [110,430] Loss:1.3633, average_loss: 1.2855
# Epoch [3/15], Iter [120,430] Loss:2.2429, average_loss: 1.3125
# Epoch [3/15], Iter [130,430] Loss:1.2981, average_loss: 1.3026
# Epoch [3/15], Iter [140,430] Loss:1.8526, average_loss: 1.2961
# Epoch [3/15], Iter [150,430] Loss:1.6172, average_loss: 1.3060
# Epoch [3/15], Iter [160,430] Loss:1.1350, average_loss: 1.3019
# Epoch [3/15], Iter [170,430] Loss:2.3963, average_loss: 1.3079
# Epoch [3/15], Iter [180,430] Loss:1.1933, average_loss: 1.3164
# Epoch [3/15], Iter [190,430] Loss:1.4158, average_loss: 1.3127
# Epoch [3/15], Iter [200,430] Loss:1.2103, average_loss: 1.3059
# Epoch [3/15], Iter [210,430] Loss:0.8528, average_loss: 1.3055
# Epoch [3/15], Iter [220,430] Loss:1.1541, average_loss: 1.2972
# Epoch [3/15], Iter [230,430] Loss:1.2102, average_loss: 1.2957
# Epoch [3/15], Iter [240,430] Loss:0.8918, average_loss: 1.2940
# Epoch [3/15], Iter [250,430] Loss:1.1572, average_loss: 1.2901
# Epoch [3/15], Iter [260,430] Loss:1.3808, average_loss: 1.2880
# Epoch [3/15], Iter [270,430] Loss:1.2374, average_loss: 1.2867
# Epoch [3/15], Iter [280,430] Loss:1.1051, average_loss: 1.2867
# Epoch [3/15], Iter [290,430] Loss:1.3784, average_loss: 1.2843
# Epoch [3/15], Iter [300,430] Loss:0.9852, average_loss: 1.2802
# Epoch [3/15], Iter [310,430] Loss:1.3758, average_loss: 1.2808
# Epoch [3/15], Iter [320,430] Loss:1.3341, average_loss: 1.2822
# Epoch [3/15], Iter [330,430] Loss:1.0562, average_loss: 1.2844
# Epoch [3/15], Iter [340,430] Loss:1.1015, average_loss: 1.2873
# Epoch [3/15], Iter [350,430] Loss:1.0047, average_loss: 1.2862
# Epoch [3/15], Iter [360,430] Loss:2.2464, average_loss: 1.2980
# Epoch [3/15], Iter [370,430] Loss:1.2253, average_loss: 1.2972
# Epoch [3/15], Iter [380,430] Loss:0.8226, average_loss: 1.2958
# Epoch [3/15], Iter [390,430] Loss:1.7224, average_loss: 1.2924
# Epoch [3/15], Iter [400,430] Loss:1.2630, average_loss: 1.2954
# Epoch [3/15], Iter [410,430] Loss:0.8972, average_loss: 1.2923
# Epoch [3/15], Iter [420,430] Loss:2.1079, average_loss: 1.2933
# Epoch [3/15], Iter [430,430] Loss:1.2497, average_loss: 1.2868
# Epoch [4/15], Iter [10,430] Loss:0.5033, average_loss: 1.0727
# Epoch [4/15], Iter [20,430] Loss:1.0015, average_loss: 1.0949
# Epoch [4/15], Iter [30,430] Loss:1.0294, average_loss: 1.1349
# Epoch [4/15], Iter [40,430] Loss:1.4675, average_loss: 1.1609
# Epoch [4/15], Iter [50,430] Loss:0.8727, average_loss: 1.1411
# Epoch [4/15], Iter [60,430] Loss:1.2780, average_loss: 1.1465
# Epoch [4/15], Iter [70,430] Loss:1.0406, average_loss: 1.1794
# Epoch [4/15], Iter [80,430] Loss:1.0486, average_loss: 1.1674
# Epoch [4/15], Iter [90,430] Loss:1.6061, average_loss: 1.1963
# Epoch [4/15], Iter [100,430] Loss:1.8036, average_loss: 1.1958
# Epoch [4/15], Iter [110,430] Loss:1.3981, average_loss: 1.2011
# Epoch [4/15], Iter [120,430] Loss:0.7615, average_loss: 1.2074
# Epoch [4/15], Iter [130,430] Loss:0.9281, average_loss: 1.1965
# Epoch [4/15], Iter [140,430] Loss:1.1725, average_loss: 1.1975
# Epoch [4/15], Iter [150,430] Loss:1.4974, average_loss: 1.1994
# Epoch [4/15], Iter [160,430] Loss:0.8550, average_loss: 1.1938
# Epoch [4/15], Iter [170,430] Loss:1.2148, average_loss: 1.1956
# Epoch [4/15], Iter [180,430] Loss:0.9669, average_loss: 1.1866
# Epoch [4/15], Iter [190,430] Loss:0.9007, average_loss: 1.1816
# Epoch [4/15], Iter [200,430] Loss:1.3968, average_loss: 1.1797
# Epoch [4/15], Iter [210,430] Loss:1.6188, average_loss: 1.1861
# Epoch [4/15], Iter [220,430] Loss:0.9340, average_loss: 1.1863
# Epoch [4/15], Iter [230,430] Loss:0.5979, average_loss: 1.1862
# Epoch [4/15], Iter [240,430] Loss:1.4211, average_loss: 1.1823
# Epoch [4/15], Iter [250,430] Loss:0.7552, average_loss: 1.1911
# Epoch [4/15], Iter [260,430] Loss:0.9017, average_loss: 1.1909
# Epoch [4/15], Iter [270,430] Loss:0.8416, average_loss: 1.1864
# Epoch [4/15], Iter [280,430] Loss:1.9988, average_loss: 1.1896
# Epoch [4/15], Iter [290,430] Loss:1.0289, average_loss: 1.1837
# Epoch [4/15], Iter [300,430] Loss:1.4692, average_loss: 1.1864
# Epoch [4/15], Iter [310,430] Loss:2.0316, average_loss: 1.1847
# Epoch [4/15], Iter [320,430] Loss:1.1918, average_loss: 1.1858
# Epoch [4/15], Iter [330,430] Loss:1.1629, average_loss: 1.1840
# Epoch [4/15], Iter [340,430] Loss:1.2228, average_loss: 1.1808
# Epoch [4/15], Iter [350,430] Loss:1.1168, average_loss: 1.1812
# Epoch [4/15], Iter [360,430] Loss:0.9684, average_loss: 1.1833
# Epoch [4/15], Iter [370,430] Loss:1.0120, average_loss: 1.1817
# Epoch [4/15], Iter [380,430] Loss:0.8114, average_loss: 1.1784
# Epoch [4/15], Iter [390,430] Loss:1.4329, average_loss: 1.1791
# Epoch [4/15], Iter [400,430] Loss:0.8952, average_loss: 1.1779
# Epoch [4/15], Iter [410,430] Loss:0.8993, average_loss: 1.1785
# Epoch [4/15], Iter [420,430] Loss:1.2232, average_loss: 1.1754
# Epoch [4/15], Iter [430,430] Loss:1.1290, average_loss: 1.1739
# Epoch [5/15], Iter [10,430] Loss:1.1594, average_loss: 1.2517
# Epoch [5/15], Iter [20,430] Loss:1.0992, average_loss: 1.1128
# Epoch [5/15], Iter [30,430] Loss:0.9047, average_loss: 1.1269
# Epoch [5/15], Iter [40,430] Loss:1.5207, average_loss: 1.1261
# Epoch [5/15], Iter [50,430] Loss:1.0089, average_loss: 1.1339
# Epoch [5/15], Iter [60,430] Loss:0.8432, average_loss: 1.1088
# Epoch [5/15], Iter [70,430] Loss:3.1463, average_loss: 1.1049
# Epoch [5/15], Iter [80,430] Loss:0.9466, average_loss: 1.0869
# Epoch [5/15], Iter [90,430] Loss:0.8621, average_loss: 1.0985
# Epoch [5/15], Iter [100,430] Loss:0.7970, average_loss: 1.0899
# Epoch [5/15], Iter [110,430] Loss:0.6754, average_loss: 1.0847
# Epoch [5/15], Iter [120,430] Loss:0.9137, average_loss: 1.0736
# Epoch [5/15], Iter [130,430] Loss:1.0042, average_loss: 1.0791
# Epoch [5/15], Iter [140,430] Loss:0.9891, average_loss: 1.0839
# Epoch [5/15], Iter [150,430] Loss:1.0488, average_loss: 1.0912
# Epoch [5/15], Iter [160,430] Loss:0.8261, average_loss: 1.0901
# Epoch [5/15], Iter [170,430] Loss:0.7084, average_loss: 1.0903
# Epoch [5/15], Iter [180,430] Loss:0.8602, average_loss: 1.0973
# Epoch [5/15], Iter [190,430] Loss:1.0719, average_loss: 1.0979
# Epoch [5/15], Iter [200,430] Loss:0.7196, average_loss: 1.0946
# Epoch [5/15], Iter [210,430] Loss:1.1284, average_loss: 1.1028
# Epoch [5/15], Iter [220,430] Loss:0.7062, average_loss: 1.1031
# Epoch [5/15], Iter [230,430] Loss:1.4967, average_loss: 1.1099
# Epoch [5/15], Iter [240,430] Loss:0.7819, average_loss: 1.1054
# Epoch [5/15], Iter [250,430] Loss:0.7144, average_loss: 1.1056
# Epoch [5/15], Iter [260,430] Loss:1.1388, average_loss: 1.1101
# Epoch [5/15], Iter [270,430] Loss:1.3169, average_loss: 1.1128
# Epoch [5/15], Iter [280,430] Loss:1.2992, average_loss: 1.1073
# Epoch [5/15], Iter [290,430] Loss:1.4151, average_loss: 1.1096
# Epoch [5/15], Iter [300,430] Loss:0.6413, average_loss: 1.1036
# Epoch [5/15], Iter [310,430] Loss:1.1183, average_loss: 1.0983
# Epoch [5/15], Iter [320,430] Loss:0.8259, average_loss: 1.0975
# Epoch [5/15], Iter [330,430] Loss:1.3615, average_loss: 1.1000
# Epoch [5/15], Iter [340,430] Loss:0.8670, average_loss: 1.0980
# Epoch [5/15], Iter [350,430] Loss:0.7974, average_loss: 1.0922
# Epoch [5/15], Iter [360,430] Loss:0.8530, average_loss: 1.0902
# Epoch [5/15], Iter [370,430] Loss:1.1859, average_loss: 1.0882
# Epoch [5/15], Iter [380,430] Loss:0.5997, average_loss: 1.0836
# Epoch [5/15], Iter [390,430] Loss:1.0288, average_loss: 1.0829
# Epoch [5/15], Iter [400,430] Loss:1.3472, average_loss: 1.0865
# Epoch [5/15], Iter [410,430] Loss:1.2782, average_loss: 1.0864
# Epoch [5/15], Iter [420,430] Loss:0.6249, average_loss: 1.0862
# Epoch [5/15], Iter [430,430] Loss:1.5913, average_loss: 1.0844
# Epoch [6/15], Iter [10,430] Loss:0.8312, average_loss: 1.0440
# Epoch [6/15], Iter [20,430] Loss:1.1781, average_loss: 1.0837
# Epoch [6/15], Iter [30,430] Loss:0.7098, average_loss: 1.0910
# Epoch [6/15], Iter [40,430] Loss:0.7887, average_loss: 1.0899
# Epoch [6/15], Iter [50,430] Loss:0.9500, average_loss: 1.0723
# Epoch [6/15], Iter [60,430] Loss:0.7295, average_loss: 1.0648
# Epoch [6/15], Iter [70,430] Loss:0.5973, average_loss: 1.0351
# Epoch [6/15], Iter [80,430] Loss:1.2791, average_loss: 1.0328
# Epoch [6/15], Iter [90,430] Loss:1.0570, average_loss: 1.0279
# Epoch [6/15], Iter [100,430] Loss:1.5060, average_loss: 1.0206
# Epoch [6/15], Iter [110,430] Loss:0.6589, average_loss: 1.0244
# Epoch [6/15], Iter [120,430] Loss:1.0762, average_loss: 1.0236
# Epoch [6/15], Iter [130,430] Loss:0.8040, average_loss: 1.0218
# Epoch [6/15], Iter [140,430] Loss:0.8800, average_loss: 1.0213
# Epoch [6/15], Iter [150,430] Loss:2.1213, average_loss: 1.0337
# Epoch [6/15], Iter [160,430] Loss:0.6800, average_loss: 1.0378
# Epoch [6/15], Iter [170,430] Loss:1.0234, average_loss: 1.0335
# Epoch [6/15], Iter [180,430] Loss:0.7771, average_loss: 1.0378
# Epoch [6/15], Iter [190,430] Loss:1.0151, average_loss: 1.0352
# Epoch [6/15], Iter [200,430] Loss:0.8868, average_loss: 1.0290
# Epoch [6/15], Iter [210,430] Loss:1.3057, average_loss: 1.0274
# Epoch [6/15], Iter [220,430] Loss:1.1445, average_loss: 1.0301
# Epoch [6/15], Iter [230,430] Loss:0.6076, average_loss: 1.0309
# Epoch [6/15], Iter [240,430] Loss:1.6704, average_loss: 1.0374
# Epoch [6/15], Iter [250,430] Loss:1.0159, average_loss: 1.0320
# Epoch [6/15], Iter [260,430] Loss:0.9856, average_loss: 1.0328
# Epoch [6/15], Iter [270,430] Loss:0.7809, average_loss: 1.0260
# Epoch [6/15], Iter [280,430] Loss:1.0300, average_loss: 1.0275
# Epoch [6/15], Iter [290,430] Loss:1.4595, average_loss: 1.0233
# Epoch [6/15], Iter [300,430] Loss:0.7549, average_loss: 1.0175
# Epoch [6/15], Iter [310,430] Loss:2.2486, average_loss: 1.0232
# Epoch [6/15], Iter [320,430] Loss:1.6085, average_loss: 1.0190
# Epoch [6/15], Iter [330,430] Loss:1.3223, average_loss: 1.0197
# Epoch [6/15], Iter [340,430] Loss:1.3430, average_loss: 1.0230
# Epoch [6/15], Iter [350,430] Loss:0.4181, average_loss: 1.0221
# Epoch [6/15], Iter [360,430] Loss:1.6706, average_loss: 1.0213
# Epoch [6/15], Iter [370,430] Loss:0.6957, average_loss: 1.0190
# Epoch [6/15], Iter [380,430] Loss:1.0621, average_loss: 1.0222
# Epoch [6/15], Iter [390,430] Loss:0.6333, average_loss: 1.0215
# Epoch [6/15], Iter [400,430] Loss:0.7751, average_loss: 1.0210
# Epoch [6/15], Iter [410,430] Loss:0.9987, average_loss: 1.0183
# Epoch [6/15], Iter [420,430] Loss:0.8292, average_loss: 1.0160
# Epoch [6/15], Iter [430,430] Loss:0.7827, average_loss: 1.0180
# Epoch [7/15], Iter [10,430] Loss:1.4860, average_loss: 0.9533
# Epoch [7/15], Iter [20,430] Loss:0.8770, average_loss: 1.0628
# Epoch [7/15], Iter [30,430] Loss:0.9988, average_loss: 1.0870
# Epoch [7/15], Iter [40,430] Loss:1.0508, average_loss: 1.0977
# Epoch [7/15], Iter [50,430] Loss:0.8773, average_loss: 1.0811
# Epoch [7/15], Iter [60,430] Loss:1.2732, average_loss: 1.0688
# Epoch [7/15], Iter [70,430] Loss:1.1125, average_loss: 1.0493
# Epoch [7/15], Iter [80,430] Loss:1.1472, average_loss: 1.0337
# Epoch [7/15], Iter [90,430] Loss:1.2632, average_loss: 1.0239
# Epoch [7/15], Iter [100,430] Loss:0.7888, average_loss: 1.0173
# Epoch [7/15], Iter [110,430] Loss:0.8292, average_loss: 1.0245
# Epoch [7/15], Iter [120,430] Loss:1.0303, average_loss: 1.0256
# Epoch [7/15], Iter [130,430] Loss:0.9989, average_loss: 1.0129
# Epoch [7/15], Iter [140,430] Loss:1.0383, average_loss: 1.0179
# Epoch [7/15], Iter [150,430] Loss:0.5667, average_loss: 1.0076
# Epoch [7/15], Iter [160,430] Loss:1.2418, average_loss: 1.0111
# Epoch [7/15], Iter [170,430] Loss:1.1998, average_loss: 1.0001
# Epoch [7/15], Iter [180,430] Loss:0.7246, average_loss: 1.0049
# Epoch [7/15], Iter [190,430] Loss:1.0083, average_loss: 1.0048
# Epoch [7/15], Iter [200,430] Loss:0.5116, average_loss: 1.0015
# Epoch [7/15], Iter [210,430] Loss:0.8678, average_loss: 1.0000
# Epoch [7/15], Iter [220,430] Loss:0.9315, average_loss: 1.0098
# Epoch [7/15], Iter [230,430] Loss:0.9736, average_loss: 1.0008
# Epoch [7/15], Iter [240,430] Loss:0.9829, average_loss: 0.9949
# Epoch [7/15], Iter [250,430] Loss:0.7602, average_loss: 0.9983
# Epoch [7/15], Iter [260,430] Loss:0.9851, average_loss: 1.0006
# Epoch [7/15], Iter [270,430] Loss:0.5981, average_loss: 0.9990
# Epoch [7/15], Iter [280,430] Loss:0.8374, average_loss: 0.9931
# Epoch [7/15], Iter [290,430] Loss:0.9379, average_loss: 0.9894
# Epoch [7/15], Iter [300,430] Loss:0.7447, average_loss: 0.9854
# Epoch [7/15], Iter [310,430] Loss:0.5872, average_loss: 0.9798
# Epoch [7/15], Iter [320,430] Loss:0.8326, average_loss: 0.9774
# Epoch [7/15], Iter [330,430] Loss:1.2334, average_loss: 0.9773
# Epoch [7/15], Iter [340,430] Loss:0.7608, average_loss: 0.9732
# Epoch [7/15], Iter [350,430] Loss:0.9847, average_loss: 0.9714
# Epoch [7/15], Iter [360,430] Loss:0.7568, average_loss: 0.9769
# Epoch [7/15], Iter [370,430] Loss:0.5701, average_loss: 0.9793
# Epoch [7/15], Iter [380,430] Loss:0.9370, average_loss: 0.9778
# Epoch [7/15], Iter [390,430] Loss:0.7840, average_loss: 0.9749
# Epoch [7/15], Iter [400,430] Loss:1.2065, average_loss: 0.9797
# Epoch [7/15], Iter [410,430] Loss:1.2795, average_loss: 0.9821
# Epoch [7/15], Iter [420,430] Loss:0.9270, average_loss: 0.9854
# Epoch [7/15], Iter [430,430] Loss:0.5805, average_loss: 0.9844
# Epoch [8/15], Iter [10,430] Loss:1.4495, average_loss: 0.9111
# Epoch [8/15], Iter [20,430] Loss:1.2700, average_loss: 0.9233
# Epoch [8/15], Iter [30,430] Loss:0.7019, average_loss: 0.9361
# Epoch [8/15], Iter [40,430] Loss:0.6783, average_loss: 1.0288
# Epoch [8/15], Iter [50,430] Loss:1.0270, average_loss: 1.0231
# Epoch [8/15], Iter [60,430] Loss:0.4430, average_loss: 0.9891
# Epoch [8/15], Iter [70,430] Loss:1.4883, average_loss: 0.9890
# Epoch [8/15], Iter [80,430] Loss:1.4319, average_loss: 0.9914
# Epoch [8/15], Iter [90,430] Loss:0.7784, average_loss: 0.9718
# Epoch [8/15], Iter [100,430] Loss:0.8124, average_loss: 0.9737
# Epoch [8/15], Iter [110,430] Loss:1.7413, average_loss: 0.9727
# Epoch [8/15], Iter [120,430] Loss:1.0297, average_loss: 0.9809
# Epoch [8/15], Iter [130,430] Loss:1.1491, average_loss: 0.9752
# Epoch [8/15], Iter [140,430] Loss:1.0837, average_loss: 0.9696
# Epoch [8/15], Iter [150,430] Loss:1.0787, average_loss: 0.9688
# Epoch [8/15], Iter [160,430] Loss:0.8468, average_loss: 0.9663
# Epoch [8/15], Iter [170,430] Loss:0.9631, average_loss: 0.9599
# Epoch [8/15], Iter [180,430] Loss:0.7683, average_loss: 0.9628
# Epoch [8/15], Iter [190,430] Loss:0.8850, average_loss: 0.9621
# Epoch [8/15], Iter [200,430] Loss:0.6535, average_loss: 0.9573
# Epoch [8/15], Iter [210,430] Loss:0.4604, average_loss: 0.9575
# Epoch [8/15], Iter [220,430] Loss:1.1798, average_loss: 0.9660
# Epoch [8/15], Iter [230,430] Loss:1.2449, average_loss: 0.9705
# Epoch [8/15], Iter [240,430] Loss:1.1707, average_loss: 0.9695
# Epoch [8/15], Iter [250,430] Loss:0.7471, average_loss: 0.9689
# Epoch [8/15], Iter [260,430] Loss:0.8691, average_loss: 0.9634
# Epoch [8/15], Iter [270,430] Loss:0.4888, average_loss: 0.9558
# Epoch [8/15], Iter [280,430] Loss:0.6032, average_loss: 0.9510
# Epoch [8/15], Iter [290,430] Loss:1.0136, average_loss: 0.9551
# Epoch [8/15], Iter [300,430] Loss:0.6550, average_loss: 0.9524
# Epoch [8/15], Iter [310,430] Loss:0.6423, average_loss: 0.9498
# Epoch [8/15], Iter [320,430] Loss:0.5700, average_loss: 0.9503
# Epoch [8/15], Iter [330,430] Loss:1.3756, average_loss: 0.9482
# Epoch [8/15], Iter [340,430] Loss:0.7423, average_loss: 0.9500
# Epoch [8/15], Iter [350,430] Loss:0.5663, average_loss: 0.9468
# Epoch [8/15], Iter [360,430] Loss:0.4399, average_loss: 0.9435
# Epoch [8/15], Iter [370,430] Loss:0.5052, average_loss: 0.9398
# Epoch [8/15], Iter [380,430] Loss:1.4376, average_loss: 0.9453
# Epoch [8/15], Iter [390,430] Loss:0.7987, average_loss: 0.9448
# Epoch [8/15], Iter [400,430] Loss:1.0253, average_loss: 0.9448
# Epoch [8/15], Iter [410,430] Loss:0.9087, average_loss: 0.9407
# Epoch [8/15], Iter [420,430] Loss:0.4849, average_loss: 0.9395
# Epoch [8/15], Iter [430,430] Loss:0.6811, average_loss: 0.9361
# Epoch [9/15], Iter [10,430] Loss:0.7421, average_loss: 0.8273
# Epoch [9/15], Iter [20,430] Loss:1.1506, average_loss: 0.8660
# Epoch [9/15], Iter [30,430] Loss:0.3965, average_loss: 0.8649
# Epoch [9/15], Iter [40,430] Loss:1.2448, average_loss: 0.8703
# Epoch [9/15], Iter [50,430] Loss:1.3280, average_loss: 0.8913
# Epoch [9/15], Iter [60,430] Loss:0.8707, average_loss: 0.9047
# Epoch [9/15], Iter [70,430] Loss:0.7786, average_loss: 0.9014
# Epoch [9/15], Iter [80,430] Loss:0.6666, average_loss: 0.8897
# Epoch [9/15], Iter [90,430] Loss:0.4371, average_loss: 0.8695
# Epoch [9/15], Iter [100,430] Loss:0.6086, average_loss: 0.8810
# Epoch [9/15], Iter [110,430] Loss:1.1203, average_loss: 0.8896
# Epoch [9/15], Iter [120,430] Loss:0.7162, average_loss: 0.8881
# Epoch [9/15], Iter [130,430] Loss:1.3039, average_loss: 0.8862
# Epoch [9/15], Iter [140,430] Loss:0.6592, average_loss: 0.8769
# Epoch [9/15], Iter [150,430] Loss:0.8980, average_loss: 0.8756
# Epoch [9/15], Iter [160,430] Loss:1.1513, average_loss: 0.8776
# Epoch [9/15], Iter [170,430] Loss:1.4478, average_loss: 0.8846
# Epoch [9/15], Iter [180,430] Loss:1.2330, average_loss: 0.8828
# Epoch [9/15], Iter [190,430] Loss:0.6731, average_loss: 0.8869
# Epoch [9/15], Iter [200,430] Loss:0.8003, average_loss: 0.8861
# Epoch [9/15], Iter [210,430] Loss:0.9479, average_loss: 0.8854
# Epoch [9/15], Iter [220,430] Loss:1.1436, average_loss: 0.8876
# Epoch [9/15], Iter [230,430] Loss:1.0718, average_loss: 0.8858
# Epoch [9/15], Iter [240,430] Loss:0.6249, average_loss: 0.8836
# Epoch [9/15], Iter [250,430] Loss:1.2316, average_loss: 0.8805
# Epoch [9/15], Iter [260,430] Loss:0.5222, average_loss: 0.8828
# Epoch [9/15], Iter [270,430] Loss:0.6345, average_loss: 0.8811
# Epoch [9/15], Iter [280,430] Loss:1.5652, average_loss: 0.8776
# Epoch [9/15], Iter [290,430] Loss:0.6315, average_loss: 0.8748
# Epoch [9/15], Iter [300,430] Loss:0.6284, average_loss: 0.8769
# Epoch [9/15], Iter [310,430] Loss:0.7863, average_loss: 0.8788
# Epoch [9/15], Iter [320,430] Loss:0.9458, average_loss: 0.8842
# Epoch [9/15], Iter [330,430] Loss:0.8620, average_loss: 0.8857
# Epoch [9/15], Iter [340,430] Loss:0.7843, average_loss: 0.8837
# Epoch [9/15], Iter [350,430] Loss:0.7176, average_loss: 0.8890
# Epoch [9/15], Iter [360,430] Loss:0.2522, average_loss: 0.8873
# Epoch [9/15], Iter [370,430] Loss:0.6874, average_loss: 0.8853
# Epoch [9/15], Iter [380,430] Loss:0.9431, average_loss: 0.8846
# Epoch [9/15], Iter [390,430] Loss:0.7204, average_loss: 0.8847
# Epoch [9/15], Iter [400,430] Loss:0.9376, average_loss: 0.8867
# Epoch [9/15], Iter [410,430] Loss:1.4983, average_loss: 0.8876
# Epoch [9/15], Iter [420,430] Loss:1.0777, average_loss: 0.8891
# Epoch [9/15], Iter [430,430] Loss:0.5247, average_loss: 0.8864
# Epoch [10/15], Iter [10,430] Loss:0.7891, average_loss: 0.9401
# Epoch [10/15], Iter [20,430] Loss:0.5464, average_loss: 0.8515
# Epoch [10/15], Iter [30,430] Loss:0.7277, average_loss: 0.8573
# Epoch [10/15], Iter [40,430] Loss:1.0036, average_loss: 0.8785
# Epoch [10/15], Iter [50,430] Loss:0.6077, average_loss: 0.8585
# Epoch [10/15], Iter [60,430] Loss:1.2007, average_loss: 0.8736
# Epoch [10/15], Iter [70,430] Loss:1.2343, average_loss: 0.8951
# Epoch [10/15], Iter [80,430] Loss:0.8526, average_loss: 0.8972
# Epoch [10/15], Iter [90,430] Loss:1.4083, average_loss: 0.8877
# Epoch [10/15], Iter [100,430] Loss:0.9170, average_loss: 0.8831
# Epoch [10/15], Iter [110,430] Loss:0.9861, average_loss: 0.8686
# Epoch [10/15], Iter [120,430] Loss:0.8967, average_loss: 0.8656
# Epoch [10/15], Iter [130,430] Loss:1.0070, average_loss: 0.8671
# Epoch [10/15], Iter [140,430] Loss:1.0734, average_loss: 0.8733
# Epoch [10/15], Iter [150,430] Loss:1.1999, average_loss: 0.8744
# Epoch [10/15], Iter [160,430] Loss:0.6122, average_loss: 0.8796
# Epoch [10/15], Iter [170,430] Loss:0.7421, average_loss: 0.8752
# Epoch [10/15], Iter [180,430] Loss:0.8433, average_loss: 0.8748
# Epoch [10/15], Iter [190,430] Loss:0.5564, average_loss: 0.8742
# Epoch [10/15], Iter [200,430] Loss:0.6367, average_loss: 0.8679
# Epoch [10/15], Iter [210,430] Loss:0.7383, average_loss: 0.8667
# Epoch [10/15], Iter [220,430] Loss:1.2461, average_loss: 0.8727
# Epoch [10/15], Iter [230,430] Loss:0.4020, average_loss: 0.8687
# Epoch [10/15], Iter [240,430] Loss:0.5666, average_loss: 0.8707
# Epoch [10/15], Iter [250,430] Loss:0.5808, average_loss: 0.8703
# Epoch [10/15], Iter [260,430] Loss:0.7603, average_loss: 0.8688
# Epoch [10/15], Iter [270,430] Loss:0.8062, average_loss: 0.8723
# Epoch [10/15], Iter [280,430] Loss:1.0726, average_loss: 0.8750
# Epoch [10/15], Iter [290,430] Loss:0.7666, average_loss: 0.8698
# Epoch [10/15], Iter [300,430] Loss:0.7596, average_loss: 0.8716
# Epoch [10/15], Iter [310,430] Loss:0.7296, average_loss: 0.8680
# Epoch [10/15], Iter [320,430] Loss:0.9275, average_loss: 0.8662
# Epoch [10/15], Iter [330,430] Loss:0.5307, average_loss: 0.8649
# Epoch [10/15], Iter [340,430] Loss:0.6540, average_loss: 0.8631
# Epoch [10/15], Iter [350,430] Loss:0.5316, average_loss: 0.8607
# Epoch [10/15], Iter [360,430] Loss:0.4426, average_loss: 0.8607
# Epoch [10/15], Iter [370,430] Loss:0.6759, average_loss: 0.8573
# Epoch [10/15], Iter [380,430] Loss:0.6196, average_loss: 0.8563
# Epoch [10/15], Iter [390,430] Loss:1.1112, average_loss: 0.8585
# Epoch [10/15], Iter [400,430] Loss:0.7306, average_loss: 0.8591
# Epoch [10/15], Iter [410,430] Loss:0.4487, average_loss: 0.8571
# Epoch [10/15], Iter [420,430] Loss:0.9540, average_loss: 0.8606
# Epoch [10/15], Iter [430,430] Loss:0.9320, average_loss: 0.8594
# Epoch [11/15], Iter [10,430] Loss:0.7063, average_loss: 0.8129
# Epoch [11/15], Iter [20,430] Loss:0.8140, average_loss: 0.7701
# Epoch [11/15], Iter [30,430] Loss:1.1750, average_loss: 0.8092
# Epoch [11/15], Iter [40,430] Loss:0.5979, average_loss: 0.8074
# Epoch [11/15], Iter [50,430] Loss:0.9974, average_loss: 0.7869
# Epoch [11/15], Iter [60,430] Loss:0.9468, average_loss: 0.8259
# Epoch [11/15], Iter [70,430] Loss:0.8430, average_loss: 0.8230
# Epoch [11/15], Iter [80,430] Loss:0.6430, average_loss: 0.8221
# Epoch [11/15], Iter [90,430] Loss:0.7145, average_loss: 0.8248
# Epoch [11/15], Iter [100,430] Loss:0.6025, average_loss: 0.8266
# Epoch [11/15], Iter [110,430] Loss:0.7231, average_loss: 0.8207
# Epoch [11/15], Iter [120,430] Loss:0.5241, average_loss: 0.8138
# Epoch [11/15], Iter [130,430] Loss:0.8161, average_loss: 0.8023
# Epoch [11/15], Iter [140,430] Loss:0.4137, average_loss: 0.8068
# Epoch [11/15], Iter [150,430] Loss:0.8782, average_loss: 0.8085
# Epoch [11/15], Iter [160,430] Loss:0.7675, average_loss: 0.8081
# Epoch [11/15], Iter [170,430] Loss:0.9952, average_loss: 0.8166
# Epoch [11/15], Iter [180,430] Loss:1.2701, average_loss: 0.8207
# Epoch [11/15], Iter [190,430] Loss:0.7723, average_loss: 0.8270
# Epoch [11/15], Iter [200,430] Loss:1.2323, average_loss: 0.8327
# Epoch [11/15], Iter [210,430] Loss:0.6881, average_loss: 0.8309
# Epoch [11/15], Iter [220,430] Loss:0.8552, average_loss: 0.8403
# Epoch [11/15], Iter [230,430] Loss:0.9125, average_loss: 0.8443
# Epoch [11/15], Iter [240,430] Loss:0.9310, average_loss: 0.8508
# Epoch [11/15], Iter [250,430] Loss:0.8048, average_loss: 0.8458
# Epoch [11/15], Iter [260,430] Loss:0.7574, average_loss: 0.8455
# Epoch [11/15], Iter [270,430] Loss:0.9202, average_loss: 0.8441
# Epoch [11/15], Iter [280,430] Loss:0.6231, average_loss: 0.8407
# Epoch [11/15], Iter [290,430] Loss:0.5741, average_loss: 0.8356
# Epoch [11/15], Iter [300,430] Loss:0.9525, average_loss: 0.8336
# Epoch [11/15], Iter [310,430] Loss:0.7185, average_loss: 0.8342
# Epoch [11/15], Iter [320,430] Loss:0.8934, average_loss: 0.8359
# Epoch [11/15], Iter [330,430] Loss:0.5273, average_loss: 0.8353
# Epoch [11/15], Iter [340,430] Loss:0.7600, average_loss: 0.8331
# Epoch [11/15], Iter [350,430] Loss:0.7151, average_loss: 0.8337
# Epoch [11/15], Iter [360,430] Loss:0.5142, average_loss: 0.8342
# Epoch [11/15], Iter [370,430] Loss:1.5004, average_loss: 0.8331
# Epoch [11/15], Iter [380,430] Loss:1.2547, average_loss: 0.8363
# Epoch [11/15], Iter [390,430] Loss:0.3250, average_loss: 0.8318
# Epoch [11/15], Iter [400,430] Loss:0.6818, average_loss: 0.8343
# Epoch [11/15], Iter [410,430] Loss:1.1504, average_loss: 0.8323
# Epoch [11/15], Iter [420,430] Loss:0.9215, average_loss: 0.8336
# Epoch [11/15], Iter [430,430] Loss:0.8657, average_loss: 0.8348
# Epoch [12/15], Iter [10,430] Loss:0.5295, average_loss: 0.8241
# Epoch [12/15], Iter [20,430] Loss:0.9050, average_loss: 0.8455
# Epoch [12/15], Iter [30,430] Loss:0.6654, average_loss: 0.8284
# Epoch [12/15], Iter [40,430] Loss:0.9622, average_loss: 0.8082
# Epoch [12/15], Iter [50,430] Loss:0.6800, average_loss: 0.8155
# Epoch [12/15], Iter [60,430] Loss:0.8151, average_loss: 0.8294
# Epoch [12/15], Iter [70,430] Loss:0.5313, average_loss: 0.8264
# Epoch [12/15], Iter [80,430] Loss:1.0185, average_loss: 0.8228
# Epoch [12/15], Iter [90,430] Loss:0.9508, average_loss: 0.8349
# Epoch [12/15], Iter [100,430] Loss:1.1100, average_loss: 0.8247
# Epoch [12/15], Iter [110,430] Loss:1.3158, average_loss: 0.8191
# Epoch [12/15], Iter [120,430] Loss:0.6744, average_loss: 0.8049
# Epoch [12/15], Iter [130,430] Loss:0.4337, average_loss: 0.8004
# Epoch [12/15], Iter [140,430] Loss:0.8712, average_loss: 0.8060
# Epoch [12/15], Iter [150,430] Loss:0.4926, average_loss: 0.7982
# Epoch [12/15], Iter [160,430] Loss:0.8395, average_loss: 0.8057
# Epoch [12/15], Iter [170,430] Loss:0.8821, average_loss: 0.8113
# Epoch [12/15], Iter [180,430] Loss:0.3519, average_loss: 0.8105
# Epoch [12/15], Iter [190,430] Loss:0.9734, average_loss: 0.8088
# Epoch [12/15], Iter [200,430] Loss:1.0402, average_loss: 0.8094
# Epoch [12/15], Iter [210,430] Loss:0.6354, average_loss: 0.8139
# Epoch [12/15], Iter [220,430] Loss:0.9663, average_loss: 0.8184
# Epoch [12/15], Iter [230,430] Loss:0.7637, average_loss: 0.8217
# Epoch [12/15], Iter [240,430] Loss:0.8919, average_loss: 0.8213
# Epoch [12/15], Iter [250,430] Loss:0.5983, average_loss: 0.8186
# Epoch [12/15], Iter [260,430] Loss:0.5825, average_loss: 0.8166
# Epoch [12/15], Iter [270,430] Loss:0.8105, average_loss: 0.8185
# Epoch [12/15], Iter [280,430] Loss:1.4116, average_loss: 0.8216
# Epoch [12/15], Iter [290,430] Loss:0.4951, average_loss: 0.8163
# Epoch [12/15], Iter [300,430] Loss:0.8845, average_loss: 0.8164
# Epoch [12/15], Iter [310,430] Loss:0.2590, average_loss: 0.8141
# Epoch [12/15], Iter [320,430] Loss:0.6530, average_loss: 0.8128
# Epoch [12/15], Iter [330,430] Loss:0.5848, average_loss: 0.8093
# Epoch [12/15], Iter [340,430] Loss:1.0735, average_loss: 0.8069
# Epoch [12/15], Iter [350,430] Loss:0.7056, average_loss: 0.8043
# Epoch [12/15], Iter [360,430] Loss:0.8765, average_loss: 0.8052
# Epoch [12/15], Iter [370,430] Loss:1.1080, average_loss: 0.8063
# Epoch [12/15], Iter [380,430] Loss:0.4252, average_loss: 0.8037
# Epoch [12/15], Iter [390,430] Loss:0.9055, average_loss: 0.8099
# Epoch [12/15], Iter [400,430] Loss:0.6617, average_loss: 0.8089
# Epoch [12/15], Iter [410,430] Loss:0.7309, average_loss: 0.8072
# Epoch [12/15], Iter [420,430] Loss:0.6761, average_loss: 0.8070
# Epoch [12/15], Iter [430,430] Loss:0.9308, average_loss: 0.8096
# Epoch [13/15], Iter [10,430] Loss:0.5072, average_loss: 0.7144
# Epoch [13/15], Iter [20,430] Loss:0.6651, average_loss: 0.7467
# Epoch [13/15], Iter [30,430] Loss:1.0117, average_loss: 0.8058
# Epoch [13/15], Iter [40,430] Loss:0.8291, average_loss: 0.7769
# Epoch [13/15], Iter [50,430] Loss:0.3397, average_loss: 0.7568
# Epoch [13/15], Iter [60,430] Loss:0.8927, average_loss: 0.7877
# Epoch [13/15], Iter [70,430] Loss:1.1119, average_loss: 0.8015
# Epoch [13/15], Iter [80,430] Loss:0.6209, average_loss: 0.7985
# Epoch [13/15], Iter [90,430] Loss:0.3918, average_loss: 0.7786
# Epoch [13/15], Iter [100,430] Loss:0.8768, average_loss: 0.7829
# Epoch [13/15], Iter [110,430] Loss:0.6166, average_loss: 0.7957
# Epoch [13/15], Iter [120,430] Loss:0.9186, average_loss: 0.8034
# Epoch [13/15], Iter [130,430] Loss:0.8590, average_loss: 0.8029
# Epoch [13/15], Iter [140,430] Loss:0.4678, average_loss: 0.7983
# Epoch [13/15], Iter [150,430] Loss:0.5635, average_loss: 0.8020
# Epoch [13/15], Iter [160,430] Loss:0.6670, average_loss: 0.8001
# Epoch [13/15], Iter [170,430] Loss:0.3610, average_loss: 0.7969
# Epoch [13/15], Iter [180,430] Loss:0.4550, average_loss: 0.7897
# Epoch [13/15], Iter [190,430] Loss:0.5668, average_loss: 0.7892
# Epoch [13/15], Iter [200,430] Loss:1.0164, average_loss: 0.7982
# Epoch [13/15], Iter [210,430] Loss:0.6449, average_loss: 0.7981
# Epoch [13/15], Iter [220,430] Loss:1.5214, average_loss: 0.7996
# Epoch [13/15], Iter [230,430] Loss:0.6668, average_loss: 0.7959
# Epoch [13/15], Iter [240,430] Loss:0.5682, average_loss: 0.7932
# Epoch [13/15], Iter [250,430] Loss:0.6681, average_loss: 0.7963
# Epoch [13/15], Iter [260,430] Loss:1.2823, average_loss: 0.8018
# Epoch [13/15], Iter [270,430] Loss:1.0635, average_loss: 0.8056
# Epoch [13/15], Iter [280,430] Loss:1.2515, average_loss: 0.8062
# Epoch [13/15], Iter [290,430] Loss:0.7060, average_loss: 0.8042
# Epoch [13/15], Iter [300,430] Loss:1.0550, average_loss: 0.8024
# Epoch [13/15], Iter [310,430] Loss:1.0045, average_loss: 0.8015
# Epoch [13/15], Iter [320,430] Loss:0.5826, average_loss: 0.8023
# Epoch [13/15], Iter [330,430] Loss:0.8205, average_loss: 0.8051
# Epoch [13/15], Iter [340,430] Loss:0.5026, average_loss: 0.8012
# Epoch [13/15], Iter [350,430] Loss:0.6889, average_loss: 0.7993
# Epoch [13/15], Iter [360,430] Loss:0.7712, average_loss: 0.7965
# Epoch [13/15], Iter [370,430] Loss:0.6425, average_loss: 0.7958
# Epoch [13/15], Iter [380,430] Loss:0.4240, average_loss: 0.7943
# Epoch [13/15], Iter [390,430] Loss:0.7382, average_loss: 0.7910
# Epoch [13/15], Iter [400,430] Loss:0.5722, average_loss: 0.7883
# Epoch [13/15], Iter [410,430] Loss:1.0903, average_loss: 0.7901
# Epoch [13/15], Iter [420,430] Loss:0.8197, average_loss: 0.7904
# Epoch [13/15], Iter [430,430] Loss:1.0390, average_loss: 0.7892
# Epoch [14/15], Iter [10,430] Loss:0.7300, average_loss: 0.6378
# Epoch [14/15], Iter [20,430] Loss:0.8383, average_loss: 0.7360
# Epoch [14/15], Iter [30,430] Loss:0.5523, average_loss: 0.7267
# Epoch [14/15], Iter [40,430] Loss:0.8262, average_loss: 0.7392
# Epoch [14/15], Iter [50,430] Loss:0.8895, average_loss: 0.7277
# Epoch [14/15], Iter [60,430] Loss:1.0085, average_loss: 0.7374
# Epoch [14/15], Iter [70,430] Loss:0.8164, average_loss: 0.7298
# Epoch [14/15], Iter [80,430] Loss:0.5418, average_loss: 0.7308
# Epoch [14/15], Iter [90,430] Loss:0.4189, average_loss: 0.7497
# Epoch [14/15], Iter [100,430] Loss:0.7220, average_loss: 0.7613
# Epoch [14/15], Iter [110,430] Loss:0.6681, average_loss: 0.7654
# Epoch [14/15], Iter [120,430] Loss:0.9730, average_loss: 0.7570
# Epoch [14/15], Iter [130,430] Loss:0.4343, average_loss: 0.7582
# Epoch [14/15], Iter [140,430] Loss:0.5109, average_loss: 0.7565
# Epoch [14/15], Iter [150,430] Loss:0.5843, average_loss: 0.7604
# Epoch [14/15], Iter [160,430] Loss:0.6574, average_loss: 0.7653
# Epoch [14/15], Iter [170,430] Loss:0.7637, average_loss: 0.7709
# Epoch [14/15], Iter [180,430] Loss:0.6728, average_loss: 0.7769
# Epoch [14/15], Iter [190,430] Loss:0.8692, average_loss: 0.7752
# Epoch [14/15], Iter [200,430] Loss:1.0348, average_loss: 0.7856
# Epoch [14/15], Iter [210,430] Loss:0.6172, average_loss: 0.7895
# Epoch [14/15], Iter [220,430] Loss:1.0678, average_loss: 0.7891
# Epoch [14/15], Iter [230,430] Loss:0.9765, average_loss: 0.7911
# Epoch [14/15], Iter [240,430] Loss:0.6460, average_loss: 0.7880
# Epoch [14/15], Iter [250,430] Loss:0.6610, average_loss: 0.7907
# Epoch [14/15], Iter [260,430] Loss:1.1359, average_loss: 0.7910
# Epoch [14/15], Iter [270,430] Loss:0.2258, average_loss: 0.7884
# Epoch [14/15], Iter [280,430] Loss:0.8499, average_loss: 0.7839
# Epoch [14/15], Iter [290,430] Loss:0.9233, average_loss: 0.7818
# Epoch [14/15], Iter [300,430] Loss:0.9100, average_loss: 0.7819
# Epoch [14/15], Iter [310,430] Loss:0.8058, average_loss: 0.7819
# Epoch [14/15], Iter [320,430] Loss:1.0305, average_loss: 0.7823
# Epoch [14/15], Iter [330,430] Loss:0.6244, average_loss: 0.7809
# Epoch [14/15], Iter [340,430] Loss:0.7205, average_loss: 0.7821
# Epoch [14/15], Iter [350,430] Loss:0.5897, average_loss: 0.7775
# Epoch [14/15], Iter [360,430] Loss:0.4986, average_loss: 0.7726
# Epoch [14/15], Iter [370,430] Loss:1.0176, average_loss: 0.7706
# Epoch [14/15], Iter [380,430] Loss:1.0159, average_loss: 0.7725
# Epoch [14/15], Iter [390,430] Loss:1.1392, average_loss: 0.7706
# Epoch [14/15], Iter [400,430] Loss:1.1130, average_loss: 0.7712
# Epoch [14/15], Iter [410,430] Loss:0.4826, average_loss: 0.7682
# Epoch [14/15], Iter [420,430] Loss:0.5498, average_loss: 0.7688
# Epoch [14/15], Iter [430,430] Loss:0.7196, average_loss: 0.7683
# Epoch [15/15], Iter [10,430] Loss:0.5091, average_loss: 0.7945
# Epoch [15/15], Iter [20,430] Loss:0.5991, average_loss: 0.7416
# Epoch [15/15], Iter [30,430] Loss:0.6387, average_loss: 0.7782
# Epoch [15/15], Iter [40,430] Loss:0.7970, average_loss: 0.7775
# Epoch [15/15], Iter [50,430] Loss:0.6429, average_loss: 0.7788
# Epoch [15/15], Iter [60,430] Loss:0.8696, average_loss: 0.7814
# Epoch [15/15], Iter [70,430] Loss:0.8403, average_loss: 0.7777
# Epoch [15/15], Iter [80,430] Loss:0.6604, average_loss: 0.7787
# Epoch [15/15], Iter [90,430] Loss:0.9905, average_loss: 0.7817
# Epoch [15/15], Iter [100,430] Loss:0.6210, average_loss: 0.7892
# Epoch [15/15], Iter [110,430] Loss:0.3750, average_loss: 0.7883
# Epoch [15/15], Iter [120,430] Loss:0.8820, average_loss: 0.7860
# Epoch [15/15], Iter [130,430] Loss:0.8030, average_loss: 0.7910
# Epoch [15/15], Iter [140,430] Loss:0.6820, average_loss: 0.7908
# Epoch [15/15], Iter [150,430] Loss:0.7292, average_loss: 0.7884
# Epoch [15/15], Iter [160,430] Loss:0.9571, average_loss: 0.7843
# Epoch [15/15], Iter [170,430] Loss:0.4126, average_loss: 0.7872
# Epoch [15/15], Iter [180,430] Loss:0.7763, average_loss: 0.7824
# Epoch [15/15], Iter [190,430] Loss:0.2223, average_loss: 0.7769
# Epoch [15/15], Iter [200,430] Loss:1.0245, average_loss: 0.7779
# Epoch [15/15], Iter [210,430] Loss:0.4913, average_loss: 0.7719
# Epoch [15/15], Iter [220,430] Loss:0.6248, average_loss: 0.7675
# Epoch [15/15], Iter [230,430] Loss:0.9665, average_loss: 0.7714
# Epoch [15/15], Iter [240,430] Loss:0.4744, average_loss: 0.7679
# Epoch [15/15], Iter [250,430] Loss:0.9453, average_loss: 0.7670
# Epoch [15/15], Iter [260,430] Loss:0.6516, average_loss: 0.7669
# Epoch [15/15], Iter [270,430] Loss:0.6528, average_loss: 0.7671
# Epoch [15/15], Iter [280,430] Loss:0.6065, average_loss: 0.7667
# Epoch [15/15], Iter [290,430] Loss:0.7946, average_loss: 0.7663
# Epoch [15/15], Iter [300,430] Loss:0.5845, average_loss: 0.7640
# Epoch [15/15], Iter [310,430] Loss:0.6303, average_loss: 0.7600
# Epoch [15/15], Iter [320,430] Loss:0.8004, average_loss: 0.7597
# Epoch [15/15], Iter [330,430] Loss:0.7324, average_loss: 0.7611
# Epoch [15/15], Iter [340,430] Loss:0.8227, average_loss: 0.7586
# Epoch [15/15], Iter [350,430] Loss:0.6925, average_loss: 0.7569
# Epoch [15/15], Iter [360,430] Loss:0.9760, average_loss: 0.7580
# Epoch [15/15], Iter [370,430] Loss:0.3804, average_loss: 0.7556
# Epoch [15/15], Iter [380,430] Loss:0.5165, average_loss: 0.7546
# Epoch [15/15], Iter [390,430] Loss:0.6918, average_loss: 0.7534
# Epoch [15/15], Iter [400,430] Loss:0.5127, average_loss: 0.7526
# Epoch [15/15], Iter [410,430] Loss:0.9737, average_loss: 0.7523
# Epoch [15/15], Iter [420,430] Loss:0.4928, average_loss: 0.7531
# Epoch [15/15], Iter [430,430] Loss:0.5331, average_loss: 0.7510

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from lab2.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    # img = img.to(device)

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])

    img = np.zeros((h, w, 3), np.uint8)
    img = img + image[:,:,::-1]

    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)
    
    # plt.imshow(img)
    return img
    #
    # plt.savefig("inference.pdf")
    #

model.eval()
img = visualize(model, './lab2/utils/Generate_dataset/images/003033.jpg')
plt.imshow(img)

# %%
def visualize_multiple_images(model, image_paths):
    num_images = len(image_paths)
    cols = 3
    rows = (num_images + cols - 1) // cols  # Calculate the number of rows needed

    plt.figure(figsize=(15, 5 * rows))

    for i, path in enumerate(image_paths):
        img = visualize(model, path)
        plt.subplot(rows, cols, i + 1)
        plt.imshow(img)
        plt.title(f"{path.split('/')[-1]}")
        plt.axis('off')

    plt.tight_layout()
    plt.savefig("inference.pdf")
    plt.show()

# List of image paths
image_paths = [
    './lab2/utils/Generate_dataset/images/003033.jpg',
    './lab2/utils/Generate_dataset/images/003037.jpg',
    './lab2/utils/Generate_dataset/images/003040.jpg',
    './lab2/utils/Generate_dataset/images/003046.jpg',
    './lab2/utils/Generate_dataset/images/003055.jpg',
    './lab2/utils/Generate_dataset/images/003080.jpg',
    './lab2/utils/Generate_dataset/images/003095.jpg',
    './lab2/utils/Generate_dataset/images/003101.jpg',
    './lab2/utils/Generate_dataset/images/003109.jpg'
]

# Visualize multiple images
visualize_multiple_images(model, image_paths)

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./lab2/utils/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 70.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    # img = img.to(device)

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)

    txt_file = open('./lab2/utils/Generate_dataset/predicted/'+os.path.basename(path)[:-4]+'.txt', 'w')

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()

import glob

model.eval()
img_names = glob.glob('./lab2/utils/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500

# %%
# %run ./lab2/utils/Generate_dataset/main.py
# Out:
# 61.77% = aeroplane AP
# 65.94% = bicycle AP
# 59.35% = bus AP
# 67.94% = car AP
# 74.89% = cat AP
# 78.01% = dog AP
# mAP = 67.98%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP
